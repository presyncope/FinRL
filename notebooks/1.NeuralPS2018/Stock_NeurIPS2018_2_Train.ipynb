# %% [markdown]
# # Stock NeurIPS2018 Part 2. Train
# This series is a reproduction of *the process in the paper Practical Deep Reinforcement Learning Approach for Stock Trading*.
#
# This is the second part of the NeurIPS2018 series, introducing how to use FinRL to make data into the gym form environment, and train DRL agents on it.
#
# Other demos can be found at the repo of [FinRL-Tutorials]((https://github.com/AI4Finance-Foundation/FinRL-Tutorials)).

# %% [markdown]
# # Part 1. Install Packages

# %%
import os
import pandas as pd

from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl import config_tickers
from finrl.main import check_and_make_directories
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR

check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# # Part 2. Build A Market Environment in OpenAI Gym-style

# %% [markdown]
# ![rl_diagram_transparent_bg.png](data:image/png;base64,...)

# %% [markdown]
# The core element in reinforcement learning are **agent** and **environment**. You can understand RL as the following process:
#
# The agent is active in a world, which is the environment. It observe its current condition as a **state**, and is allowed to do certain **actions**. After the agent execute an action, it will arrive at a new state. At the same time, the environment will have feedback to the agent called **reward**, a numerical signal that tells how good or bad the new state is. As the figure above, agent and environment will keep doing this interaction.
#
# The goal of agent is to get as much cumulative reward as possible. Reinforcement learning is the method that agent learns to improve its behavior and achieve that goal.

# %% [markdown]
# To achieve this in Python, we follow the OpenAI gym style to build the stock data into environment.
#
# state-action-reward are specified as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes the price data and technical indicators based on the past data. It will learn by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 constituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.

# %% [markdown]
# ## Read data
#
# We first read the .csv file of our training data into dataframe.

# %%
train = pd.read_csv('train_data.csv')

# If you are not using the data generated from part 1 of this tutorial, make sure 
# it has the columns and index in the form that could be make into the environment. 
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']

# %% [markdown]
# ## Construct the environment

# %% [markdown]
# Calculate and specify the parameters we need for constructing the environment.

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 3: Train DRL Agents
# * Here, the DRL algorithms are from **[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)**. It's a library that implemented popular DRL algorithms using pytorch, succeeding to its old version: Stable Baselines.
# * Users are also encouraged to try **[ElegantRL](https://github.com/AI4Finance-Foundation/ElegantRL)** and **[Ray RLlib](https://github.com/ray-project/ray)**.

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ## Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to results/a2c
# /home/nuk/anaconda3/envs/finrl-env/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 162         |
# |    iterations         | 100         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.13        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -64.4       |
# |    reward             | 0.015814116 |
# |    std                | 1           |
# |    value_loss         | 4.61        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 168        |
# |    iterations         | 200        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.11      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 12         |
# |    reward             | -1.2908176 |
# |    std                | 1          |
# |    value_loss         | 0.75       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 300      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0.0528   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -232     |
# |    reward             | 6.553251 |
# |    std                | 1        |
# |    value_loss         | 36.2     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 178         |
# |    iterations         | 400         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0.101       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 260         |
# |    reward             | -0.89301914 |
# |    std                | 1           |
# |    value_loss         | 43.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 181        |
# |    iterations         | 500        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 326        |
# |    reward             | -10.772296 |
# |    std                | 1          |
# |    value_loss         | 109        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 180         |
# |    iterations         | 600         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | -0.326      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 172         |
# |    reward             | 0.017039794 |
# |    std                | 1           |
# |    value_loss         | 21.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 183        |
# |    iterations         | 700        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.11      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -138       |
# |    reward             | -3.7542582 |
# |    std                | 1          |
# |    value_loss         | 11.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 182        |
# |    iterations         | 800        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0927     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 15.7       |
# |    reward             | -4.6303725 |
# |    std                | 1          |
# |    value_loss         | 0.517      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 900        |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.014     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 32         |
# |    reward             | -1.0938962 |
# |    std                | 1          |
# |    value_loss         | 1.7        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 1000       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0885     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 44.4       |
# |    reward             | -3.4730961 |
# |    std                | 1          |
# |    value_loss         | 1.6        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 1100      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -207      |
# |    reward             | 4.5352826 |
# |    std                | 1         |
# |    value_loss         | 31.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 148         |
# |    iterations         | 1200        |
# |    time_elapsed       | 40          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.0963     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -128        |
# |    reward             | -0.16493714 |
# |    std                | 0.998       |
# |    value_loss         | 11.8        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1300     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -30.8    |
# |    reward             | -3.97498 |
# |    std                | 0.999    |
# |    value_loss         | 5.71     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 1400      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 206       |
# |    reward             | 2.0667133 |
# |    std                | 0.999     |
# |    value_loss         | 39.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 1500      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 213       |
# |    reward             | 3.6446972 |
# |    std                | 1         |
# |    value_loss         | 30.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 1600      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 437       |
# |    reward             | 1.9294512 |
# |    std                | 1         |
# |    value_loss         | 138       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 1700     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -174     |
# |    reward             | 8.363328 |
# |    std                | 1        |
# |    value_loss         | 141      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1800     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0.0264   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -36.8    |
# |    reward             | 2.972266 |
# |    std                | 0.999    |
# |    value_loss         | 1.45     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 1900       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.00442    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -74.7      |
# |    reward             | 0.60134375 |
# |    std                | 0.999      |
# |    value_loss         | 4.14       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 2000      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -34.6     |
# |    reward             | 1.1538321 |
# |    std                | 0.998     |
# |    value_loss         | 2.09      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 2100     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 63.6     |
# |    reward             | 2.746546 |
# |    std                | 0.998    |
# |    value_loss         | 6.77     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 2200      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | 83        |
# |    reward             | -9.757466 |
# |    std                | 0.997     |
# |    value_loss         | 7         |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 2300       |
# |    time_elapsed       | 62         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -2.79e+03  |
# |    reward             | -1.7432969 |
# |    std                | 0.997      |
# |    value_loss         | 4.91e+03   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 2400       |
# |    time_elapsed       | 64         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 72.6       |
# |    reward             | 0.94262815 |
# |    std                | 0.999      |
# |    value_loss         | 7.97       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 2500      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -68.6     |
# |    reward             | 1.1921524 |
# |    std                | 1         |
# |    value_loss         | 3.12      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 2600      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | 14.9      |
# |    reward             | 3.5531096 |
# |    std                | 0.998     |
# |    value_loss         | 3.91      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 2700       |
# |    time_elapsed       | 72         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 6.05       |
# |    reward             | -1.1780399 |
# |    std                | 0.998      |
# |    value_loss         | 0.572      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 2800      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 552       |
# |    reward             | 3.5681436 |
# |    std                | 0.997     |
# |    value_loss         | 205       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 2900      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -88.2     |
# |    reward             | 1.3947933 |
# |    std                | 0.997     |
# |    value_loss         | 5.24      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 3000      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 23.9      |
# |    reward             | 0.4511374 |
# |    std                | 0.995     |
# |    value_loss         | 0.995     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 3100       |
# |    time_elapsed       | 83         |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | 33.9       |
# |    reward             | -1.2081405 |
# |    std                | 0.996      |
# |    value_loss         | 2.7        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 3200       |
# |    time_elapsed       | 86         |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -54.9      |
# |    reward             | -3.4710307 |
# |    std                | 1          |
# |    value_loss         | 17.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 3300      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | 8.18      |
# |    reward             | 3.3397937 |
# |    std                | 1         |
# |    value_loss         | 2.83      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 3400      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0979    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 63.6      |
# |    reward             | 2.9304874 |
# |    std                | 1         |
# |    value_loss         | 8.79      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 3500       |
# |    time_elapsed       | 94         |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 122        |
# |    reward             | -0.7125637 |
# |    std                | 1          |
# |    value_loss         | 12         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 3600      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -59       |
# |    reward             | 1.5588679 |
# |    std                | 1         |
# |    value_loss         | 2.84      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 3700      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 164       |
# |    reward             | 0.5305878 |
# |    std                | 1         |
# |    value_loss         | 19.7      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 172         |
# |    iterations         | 3800        |
# |    time_elapsed       | 110         |
# |    total_timesteps    | 19000       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3799        |
# |    policy_loss        | 164         |
# |    reward             | -0.40293467 |
# |    std                | 1           |
# |    value_loss         | 15.6        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 3900       |
# |    time_elapsed       | 104        |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | -133       |
# |    reward             | 0.13961093 |
# |    std                | 1          |
# |    value_loss         | 10.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 4000     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -102     |
# |    reward             | 4.081879 |
# |    std                | 1        |
# |    value_loss         | 12.6     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 4100       |
# |    time_elapsed       | 110        |
# |    total_timesteps    | 20500      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4099       |
# |    policy_loss        | -40.2      |
# |    reward             | 0.12603667 |
# |    std                | 1          |
# |    value_loss         | 2.57       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 4200       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 21000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4199       |
# |    policy_loss        | -153       |
# |    reward             | 0.91315484 |
# |    std                | 0.998      |
# |    value_loss         | 15.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 4300      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -104      |
# |    reward             | 3.3176649 |
# |    std                | 0.999     |
# |    value_loss         | 7.23      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 4400      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | 97.9      |
# |    reward             | 2.2686958 |
# |    std                | 1         |
# |    value_loss         | 8.96      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 4500      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 118       |
# |    reward             | 0.8817616 |
# |    std                | 1         |
# |    value_loss         | 11.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 4600      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 150       |
# |    reward             | 3.2271893 |
# |    std                | 0.999     |
# |    value_loss         | 14.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 4700       |
# |    time_elapsed       | 126        |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -128       |
# |    reward             | 0.22872707 |
# |    std                | 0.999      |
# |    value_loss         | 14.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 4800       |
# |    time_elapsed       | 128        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -52.2      |
# |    reward             | -1.0467356 |
# |    std                | 0.997      |
# |    value_loss         | 3.31       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 4900      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -122      |
# |    reward             | 0.9897364 |
# |    std                | 0.997     |
# |    value_loss         | 12.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 5000       |
# |    time_elapsed       | 134        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -53        |
# |    reward             | -3.2755268 |
# |    std                | 0.998      |
# |    value_loss         | 4.86       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 5100      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -104      |
# |    reward             | 1.9271616 |
# |    std                | 0.999     |
# |    value_loss         | 21        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 5200     |
# |    time_elapsed       | 139      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -710     |
# |    reward             | 5.332783 |
# |    std                | 0.999    |
# |    value_loss         | 365      |
# ------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5715462.53
# total_reward: 4715462.53
# total_cost: 6954.93
# total_trades: 39830
# Sharpe: 0.991
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 176         |
# |    iterations         | 5300        |
# |    time_elapsed       | 150         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | -47.2       |
# |    reward             | -0.30170098 |
# |    std                | 0.999       |
# |    value_loss         | 1.22        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 5400       |
# |    time_elapsed       | 144        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -34        |
# |    reward             | -0.3536178 |
# |    std                | 1          |
# |    value_loss         | 5.12       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 5500      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.19e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -121      |
# |    reward             | 1.9611931 |
# |    std                | 1         |
# |    value_loss         | 35.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 5600      |
# |    time_elapsed       | 150       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -208      |
# |    reward             | 0.8627608 |
# |    std                | 1         |
# |    value_loss         | 40.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 5700       |
# |    time_elapsed       | 152        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -37.1      |
# |    reward             | -3.1916955 |
# |    std                | 1.01       |
# |    value_loss         | 5.79       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 5800     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | -9.53    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 29.2     |
# |    reward             | 2.420821 |
# |    std                | 1.01     |
# |    value_loss         | 30.1     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 186         |
# |    iterations         | 5900        |
# |    time_elapsed       | 158         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -1.13       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | -17.3       |
# |    reward             | -0.19927825 |
# |    std                | 1.01        |
# |    value_loss         | 0.269       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 186         |
# |    iterations         | 6000        |
# |    time_elapsed       | 160         |
# |    total_timesteps    | 30000       |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5999        |
# |    policy_loss        | 78.6        |
# |    reward             | -0.31567892 |
# |    std                | 1.01        |
# |    value_loss         | 5.56        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 6100       |
# |    time_elapsed       | 163        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -38.4      |
# |    reward             | -2.1854894 |
# |    std                | 1.01       |
# |    value_loss         | 3          |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 6200       |
# |    time_elapsed       | 166        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | 21.9       |
# |    reward             | -1.2244993 |
# |    std                | 1.01       |
# |    value_loss         | 0.511      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 6300      |
# |    time_elapsed       | 168       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -302      |
# |    reward             | 0.9712642 |
# |    std                | 1.01      |
# |    value_loss         | 84.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 6400      |
# |    time_elapsed       | 171       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 160       |
# |    reward             | 1.3623841 |
# |    std                | 1.01      |
# |    value_loss         | 12.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 6500       |
# |    time_elapsed       | 174        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 47.1       |
# |    reward             | -4.6999106 |
# |    std                | 1.01       |
# |    value_loss         | 9.14       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 185         |
# |    iterations         | 6600        |
# |    time_elapsed       | 177         |
# |    total_timesteps    | 33000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6599        |
# |    policy_loss        | -93.7       |
# |    reward             | -0.47000203 |
# |    std                | 1.01        |
# |    value_loss         | 9.99        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 184        |
# |    iterations         | 6700       |
# |    time_elapsed       | 181        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | -0.00533   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -834       |
# |    reward             | -6.5645084 |
# |    std                | 1.02       |
# |    value_loss         | 494        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 184        |
# |    iterations         | 6800       |
# |    time_elapsed       | 184        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | -218       |
# |    reward             | -1.2197508 |
# |    std                | 1.02       |
# |    value_loss         | 28.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 176       |
# |    iterations         | 6900      |
# |    time_elapsed       | 195       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | 155       |
# |    reward             | 7.3659067 |
# |    std                | 1.02      |
# |    value_loss         | 56.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 7000      |
# |    time_elapsed       | 190       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | 92.5      |
# |    reward             | 0.3718689 |
# |    std                | 1.02      |
# |    value_loss         | 6.53      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 7100      |
# |    time_elapsed       | 193       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 10.7      |
# |    reward             | 0.6487519 |
# |    std                | 1.02      |
# |    value_loss         | 0.947     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 183        |
# |    iterations         | 7200       |
# |    time_elapsed       | 196        |
# |    total_timesteps    | 36000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7199       |
# |    policy_loss        | -451       |
# |    reward             | 0.83694106 |
# |    std                | 1.02       |
# |    value_loss         | 132        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 182         |
# |    iterations         | 7300        |
# |    time_elapsed       | 199         |
# |    total_timesteps    | 36500       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7299        |
# |    policy_loss        | 99.4        |
# |    reward             | -0.54879004 |
# |    std                | 1.02        |
# |    value_loss         | 14.4        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 182        |
# |    iterations         | 7400       |
# |    time_elapsed       | 202        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -40.9      |
# |    reward             | -6.7640514 |
# |    std                | 1.02       |
# |    value_loss         | 16.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 181        |
# |    iterations         | 7500       |
# |    time_elapsed       | 206        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 25.9       |
# |    reward             | -4.9907503 |
# |    std                | 1.02       |
# |    value_loss         | 4.65       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 7600      |
# |    time_elapsed       | 209       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -164      |
# |    reward             | 2.6498928 |
# |    std                | 1.02      |
# |    value_loss         | 17.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 181       |
# |    iterations         | 7700      |
# |    time_elapsed       | 212       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -73.1     |
# |    reward             | 1.0594903 |
# |    std                | 1.02      |
# |    value_loss         | 4.49      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 180        |
# |    iterations         | 7800       |
# |    time_elapsed       | 215        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -19.4      |
# |    reward             | -0.8084056 |
# |    std                | 1.02       |
# |    value_loss         | 1.37       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 180       |
# |    iterations         | 7900      |
# |    time_elapsed       | 218       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 279       |
# |    reward             | 4.0891895 |
# |    std                | 1.02      |
# |    value_loss         | 75.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 180        |
# |    iterations         | 8000       |
# |    time_elapsed       | 221        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -217       |
# |    reward             | -2.9322727 |
# |    std                | 1.03       |
# |    value_loss         | 35.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 180       |
# |    iterations         | 8100      |
# |    time_elapsed       | 224       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 51.8      |
# |    reward             | 17.256731 |
# |    std                | 1.03      |
# |    value_loss         | 17.5      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 180        |
# |    iterations         | 8200       |
# |    time_elapsed       | 227        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | 35.2       |
# |    reward             | 0.19558828 |
# |    std                | 1.03       |
# |    value_loss         | 0.998      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 179        |
# |    iterations         | 8300       |
# |    time_elapsed       | 231        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | -17.9      |
# |    reward             | -1.5668355 |
# |    std                | 1.03       |
# |    value_loss         | 1.06       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 179         |
# |    iterations         | 8400        |
# |    time_elapsed       | 234         |
# |    total_timesteps    | 42000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8399        |
# |    policy_loss        | -123        |
# |    reward             | -0.61994445 |
# |    std                | 1.03        |
# |    value_loss         | 9.1         |
# ---------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 173            |
# |    iterations         | 8500           |
# |    time_elapsed       | 245            |
# |    total_timesteps    | 42500          |
# | train/                |                |
# |    entropy_loss       | -41.9          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 8499           |
# |    policy_loss        | 8.65           |
# |    reward             | -0.00089667016 |
# |    std                | 1.03           |
# |    value_loss         | 1.05           |
# ------------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 178        |
# |    iterations         | 8600       |
# |    time_elapsed       | 240        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 34.8       |
# |    reward             | -19.805534 |
# |    std                | 1.03       |
# |    value_loss         | 27.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 178       |
# |    iterations         | 8700      |
# |    time_elapsed       | 243       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0.000547  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 10.6      |
# |    reward             | 2.0676851 |
# |    std                | 1.03      |
# |    value_loss         | 1.51      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 178       |
# |    iterations         | 8800      |
# |    time_elapsed       | 246       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -68.5     |
# |    reward             | 1.0706589 |
# |    std                | 1.03      |
# |    value_loss         | 3.67      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 178        |
# |    iterations         | 8900       |
# |    time_elapsed       | 249        |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | 62.4       |
# |    reward             | 0.55719763 |
# |    std                | 1.03       |
# |    value_loss         | 4.38       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 172        |
# |    iterations         | 9000       |
# |    time_elapsed       | 260        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | 59.8       |
# |    reward             | -1.0217929 |
# |    std                | 1.03       |
# |    value_loss         | 7.39       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 178       |
# |    iterations         | 9100      |
# |    time_elapsed       | 255       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 15.8      |
# |    reward             | 2.7957308 |
# |    std                | 1.03      |
# |    value_loss         | 0.803     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 9200     |
# |    time_elapsed       | 258      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -41.9    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | -43.8    |
# |    reward             | 4.067888 |
# |    std                | 1.03     |
# |    value_loss         | 10.2     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 177        |
# |    iterations         | 9300       |
# |    time_elapsed       | 262        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -175       |
# |    reward             | 0.62662977 |
# |    std                | 1.03       |
# |    value_loss         | 22.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 177        |
# |    iterations         | 9400       |
# |    time_elapsed       | 265        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | 162        |
# |    reward             | 0.07288422 |
# |    std                | 1.03       |
# |    value_loss         | 19.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 177       |
# |    iterations         | 9500      |
# |    time_elapsed       | 268       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | 179       |
# |    reward             | 1.3597106 |
# |    std                | 1.03      |
# |    value_loss         | 20.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 176        |
# |    iterations         | 9600       |
# |    time_elapsed       | 271        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -42        |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -410       |
# |    reward             | 0.59100115 |
# |    std                | 1.03       |
# |    value_loss         | 117        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 176         |
# |    iterations         | 9700        |
# |    time_elapsed       | 274         |
# |    total_timesteps    | 48500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 1.79e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9699        |
# |    policy_loss        | 123         |
# |    reward             | -0.30741423 |
# |    std                | 1.03        |
# |    value_loss         | 11.6        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 176       |
# |    iterations         | 9800      |
# |    time_elapsed       | 277       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | -28.6     |
# |    reward             | 9.3270645 |
# |    std                | 1.03      |
# |    value_loss         | 59.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 176      |
# |    iterations         | 9900     |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 49500    |
# | train/                |          |
# |    entropy_loss       | -42      |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9899     |
# |    policy_loss        | 37.4     |
# |    reward             | 0.701908 |
# |    std                | 1.03     |
# |    value_loss         | 1.18     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 176         |
# |    iterations         | 10000       |
# |    time_elapsed       | 283         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 5.64        |
# |    reward             | -0.96726346 |
# |    std                | 1.03        |
# |    value_loss         | 1.74        |
# ---------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device
# Logging to results/ddpg

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None
# Out:
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 5526799.22
# total_reward: 4526799.22
# total_cost: 5142.66
# total_trades: 36468
# Sharpe: 0.983
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 107       |
# |    time_elapsed    | 107       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 28        |
# |    critic_loss     | 24        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11471     |
# |    reward          | 7.8295217 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 106       |
# |    time_elapsed    | 217       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 6.53      |
# |    critic_loss     | 4.62      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23043     |
# |    reward          | 7.8295217 |
# ----------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 4698577.98
# total_reward: 3698577.98
# total_cost: 999.00
# total_trades: 31812
# Sharpe: 0.821
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 104       |
# |    time_elapsed    | 330       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -2.03     |
# |    critic_loss     | 3.7       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34615     |
# |    reward          | 7.8295217 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 103       |
# |    time_elapsed    | 447       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -7.43     |
# |    critic_loss     | 2.14      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46187     |
# |    reward          | 7.8295217 |
# ----------------------------------

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
    "device" : "cpu",
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128, 'device': 'cpu'}
# Using cpu device
# Logging to results/ppo

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None
# Out:
# --------------------------------------
# | time/              |               |
# |    fps             | 296           |
# |    iterations      | 1             |
# |    time_elapsed    | 6             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0072749234 |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017408364 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00166     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.9         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0195     |
# |    reward               | 0.71386683  |
# |    std                  | 1           |
# |    value_loss           | 15          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013376379 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00222     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | -1.7586803  |
# |    std                  | 1           |
# |    value_loss           | 65.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015214193 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.0172      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0108     |
# |    reward               | 3.2616286   |
# |    std                  | 1.01        |
# |    value_loss           | 41.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014848858 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0142     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.8         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.019      |
# |    reward               | 3.3037424   |
# |    std                  | 1.01        |
# |    value_loss           | 19.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 6           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.023367826 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00128    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0223     |
# |    reward               | 2.1430929   |
# |    std                  | 1.01        |
# |    value_loss           | 53.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016337836 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.0119     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 39.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0158     |
# |    reward               | 1.320193    |
# |    std                  | 1.01        |
# |    value_loss           | 65.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 8           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.020721063 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.0103     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.05        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0223     |
# |    reward               | 0.87105465  |
# |    std                  | 1.01        |
# |    value_loss           | 24.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 9           |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018486869 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.0184      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.64        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0235     |
# |    reward               | 0.9866999   |
# |    std                  | 1.01        |
# |    value_loss           | 40          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 10          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.019994047 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.00688    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.6        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0222     |
# |    reward               | 0.8264603   |
# |    std                  | 1.02        |
# |    value_loss           | 59.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 11          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021540768 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.0304     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.1        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | 1.5611049   |
# |    std                  | 1.02        |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 12          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015137904 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.0208     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.3         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0176     |
# |    reward               | 0.102078445 |
# |    std                  | 1.02        |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 13          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.029270098 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.000413   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0209     |
# |    reward               | 0.25458276  |
# |    std                  | 1.03        |
# |    value_loss           | 34.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 14          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016775787 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.00513    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | 2.1134083   |
# |    std                  | 1.03        |
# |    value_loss           | 46.4        |
# -----------------------------------------
# day: 2892, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 3480856.19
# total_reward: 2480856.19
# total_cost: 300909.90
# total_trades: 79362
# Sharpe: 0.769
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 15          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025069624 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.0349     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.6        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0218     |
# |    reward               | 3.1602626   |
# |    std                  | 1.03        |
# |    value_loss           | 21.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 16          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021799717 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | -0.00986    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.2        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0231     |
# |    reward               | 0.018953444 |
# |    std                  | 1.03        |
# |    value_loss           | 30.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 17          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.025359802 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0039      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.4        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0187     |
# |    reward               | 0.60287327  |
# |    std                  | 1.04        |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 18          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022257403 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.0111     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0169     |
# |    reward               | -0.60204226 |
# |    std                  | 1.04        |
# |    value_loss           | 34.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 267         |
# |    iterations           | 19          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022455443 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.0149     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.85        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | -0.42457345 |
# |    std                  | 1.04        |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 20          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016573956 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.00897     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.5        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -0.45708716 |
# |    std                  | 1.04        |
# |    value_loss           | 38.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 21          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026128802 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.0141      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.4        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0181     |
# |    reward               | -7.136929   |
# |    std                  | 1.04        |
# |    value_loss           | 31          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 22          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017536085 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.0256      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.72        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0154     |
# |    reward               | 3.1996047   |
# |    std                  | 1.04        |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 23          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.035401214 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | 0.0319      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.53        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0168     |
# |    reward               | 0.25633368  |
# |    std                  | 1.05        |
# |    value_loss           | 28.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 279         |
# |    iterations           | 24          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021420175 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | 0.00039     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.3        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0184     |
# |    reward               | 3.194069    |
# |    std                  | 1.05        |
# |    value_loss           | 51.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 279        |
# |    iterations           | 25         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02743853 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.5      |
# |    explained_variance   | 0.0121     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 35.2       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0175    |
# |    reward               | -1.2491515 |
# |    std                  | 1.05       |
# |    value_loss           | 36.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 280        |
# |    iterations           | 26         |
# |    time_elapsed         | 190        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02077891 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.6      |
# |    explained_variance   | 0.0132     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.48       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0195    |
# |    reward               | 1.0528374  |
# |    std                  | 1.05       |
# |    value_loss           | 12.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 280        |
# |    iterations           | 27         |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02918917 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.6      |
# |    explained_variance   | 0.00858    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 13.9       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0124    |
# |    reward               | -1.01518   |
# |    std                  | 1.05       |
# |    value_loss           | 50.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 28          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.030085584 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | -0.00402    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | -0.5830013  |
# |    std                  | 1.06        |
# |    value_loss           | 57.2        |
# -----------------------------------------
# day: 2892, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 4109670.03
# total_reward: 3109670.03
# total_cost: 247297.08
# total_trades: 75209
# Sharpe: 0.817
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 29          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.032815285 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | -0.0124     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.24        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0107     |
# |    reward               | -0.35507247 |
# |    std                  | 1.06        |
# |    value_loss           | 19.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 281        |
# |    iterations           | 30         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02305263 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.8      |
# |    explained_variance   | 0.0167     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 39.5       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0092    |
# |    reward               | 0.46876544 |
# |    std                  | 1.06       |
# |    value_loss           | 73.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 31          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.021559536 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | -0.0203     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.1        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0108     |
# |    reward               | 1.3492848   |
# |    std                  | 1.06        |
# |    value_loss           | 57.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 32          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.027015133 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0.0489      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.93        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0114     |
# |    reward               | -0.62239873 |
# |    std                  | 1.06        |
# |    value_loss           | 17          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 33          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.026707238 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.0167      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0146     |
# |    reward               | -0.524345   |
# |    std                  | 1.07        |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 34          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.020892914 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0.0349      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0109     |
# |    reward               | 0.46127594  |
# |    std                  | 1.07        |
# |    value_loss           | 56.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 35          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.024012253 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.00585     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.2        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0113     |
# |    reward               | -0.23226911 |
# |    std                  | 1.07        |
# |    value_loss           | 46.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 36          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.020984259 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.07        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0168     |
# |    reward               | -3.0922291  |
# |    std                  | 1.07        |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 37          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.030531675 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 0.0321      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00729    |
# |    reward               | -0.49701205 |
# |    std                  | 1.07        |
# |    value_loss           | 56.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 38          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.029449465 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.0256      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.9        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00964    |
# |    reward               | -8.35413    |
# |    std                  | 1.07        |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 39          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.039597332 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.0274      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00869    |
# |    reward               | -2.311569   |
# |    std                  | 1.07        |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 40          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.023691177 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.5        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.016      |
# |    reward               | -0.29168633 |
# |    std                  | 1.08        |
# |    value_loss           | 50.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 41          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.019161168 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | 0.00733     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.2        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0098     |
# |    reward               | 0.14446823  |
# |    std                  | 1.08        |
# |    value_loss           | 68.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 42          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.034643248 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | 0.0237      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 65.4        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00698    |
# |    reward               | -1.0987419  |
# |    std                  | 1.08        |
# |    value_loss           | 65.4        |
# -----------------------------------------
# day: 2892, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 3813386.01
# total_reward: 2813386.01
# total_cost: 239697.03
# total_trades: 74343
# Sharpe: 0.774
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 43          |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.036898978 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.4       |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.35        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.01       |
# |    reward               | 0.7947233   |
# |    std                  | 1.08        |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 44          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.018329393 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.4       |
# |    explained_variance   | 0.0343      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | 0.14529224  |
# |    std                  | 1.08        |
# |    value_loss           | 83.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 283        |
# |    iterations           | 45         |
# |    time_elapsed         | 324        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02674805 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.4      |
# |    explained_variance   | 0.015      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 26.5       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00825   |
# |    reward               | 1.3739806  |
# |    std                  | 1.08       |
# |    value_loss           | 55.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 283        |
# |    iterations           | 46         |
# |    time_elapsed         | 332        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03338454 |
# |    clip_fraction        | 0.275      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.5      |
# |    explained_variance   | 0.0462     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 9.35       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00701   |
# |    reward               | -4.336577  |
# |    std                  | 1.08       |
# |    value_loss           | 22.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 47          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.028910104 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | 0.0336      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 29.4        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | 0.99447405  |
# |    std                  | 1.09        |
# |    value_loss           | 66.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 48          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.019184709 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.0158      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.7        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0105     |
# |    reward               | 9.113492    |
# |    std                  | 1.09        |
# |    value_loss           | 87.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 49          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.02640199  |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.00778     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00803    |
# |    reward               | -0.22763018 |
# |    std                  | 1.09        |
# |    value_loss           | 86          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 50          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.024293873 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0.0473      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.57        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0103     |
# |    reward               | -1.7668353  |
# |    std                  | 1.09        |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 51          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.03191635  |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0.0126      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.8        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00933    |
# |    reward               | -0.24097204 |
# |    std                  | 1.09        |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 52          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.042462464 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0.0122      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.1        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00621    |
# |    reward               | -5.4807334  |
# |    std                  | 1.09        |
# |    value_loss           | 83.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 53          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.022260748 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | 0.00274     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.5        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0035     |
# |    reward               | 1.6106898   |
# |    std                  | 1.1         |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 54          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.025458265 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | 0.008       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.2        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0118     |
# |    reward               | 1.321687    |
# |    std                  | 1.1         |
# |    value_loss           | 82.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 283        |
# |    iterations           | 55         |
# |    time_elapsed         | 396        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.03574189 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -43.9      |
# |    explained_variance   | -0.0113    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 27.2       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.000155  |
# |    reward               | 3.7802534  |
# |    std                  | 1.1        |
# |    value_loss           | 72.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 56          |
# |    time_elapsed         | 404         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.014908591 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | 0.0154      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.2        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00771    |
# |    reward               | 1.2513967   |
# |    std                  | 1.1         |
# |    value_loss           | 41.9        |
# -----------------------------------------
# day: 2892, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 3706540.96
# total_reward: 2706540.96
# total_cost: 266368.83
# total_trades: 75879
# Sharpe: 0.792
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 57          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.026261847 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | 0.02        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 54.6        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0135     |
# |    reward               | 0.1497041   |
# |    std                  | 1.11        |
# |    value_loss           | 57.8        |
# ...
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.026974704 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.2        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00454    |
# |    reward               | -0.6864185  |
# |    std                  | 1.15        |
# |    value_loss           | 37          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 81          |
# |    time_elapsed         | 581         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.02216885  |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0.0459      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.8        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0126     |
# |    reward               | -0.58434063 |
# |    std                  | 1.15        |
# |    value_loss           | 73.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 82           |
# |    time_elapsed         | 588          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.025019934  |
# |    clip_fraction        | 0.238        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.2        |
# |    explained_variance   | 0.0287       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.2         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0127      |
# |    reward               | -0.031250257 |
# |    std                  | 1.15         |
# |    value_loss           | 78.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 83          |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.032667376 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.2       |
# |    explained_variance   | 0.0443      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 50.2        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00857    |
# |    reward               | -1.301653   |
# |    std                  | 1.15        |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 84          |
# |    time_elapsed         | 602         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.030320365 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.79        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00884    |
# |    reward               | 0.3116399   |
# |    std                  | 1.15        |
# |    value_loss           | 14.3        |
# -----------------------------------------
# day: 2892, episode: 210
# begin_total_asset: 1000000.00
# end_total_asset: 4240514.22
# total_reward: 3240514.22
# total_cost: 280109.90
# total_trades: 74101
# Sharpe: 0.810
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 85          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.037219286 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.3       |
# |    explained_variance   | -0.00978    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.1        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0056     |
# |    reward               | 0.13676426  |
# |    std                  | 1.16        |
# |    value_loss           | 78.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 86          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.044942286 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | -0.00324    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.6        |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.00874    |
# |    reward               | -0.8429424  |
# |    std                  | 1.16        |
# |    value_loss           | 104         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 87         |
# |    time_elapsed         | 624        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.06827445 |
# |    clip_fraction        | 0.354      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45.5      |
# |    explained_variance   | 0.015      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 15.3       |
# |    n_updates            | 860        |
# |    policy_gradient_loss | 0.0053     |
# |    reward               | 1.3296152  |
# |    std                  | 1.16       |
# |    value_loss           | 28.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 88          |
# |    time_elapsed         | 632         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.037365854 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.5       |
# |    explained_variance   | 0.00085     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 78.5        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00651    |
# |    reward               | -1.802179   |
# |    std                  | 1.16        |
# |    value_loss           | 88.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 89           |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.04079594   |
# |    clip_fraction        | 0.275        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.6        |
# |    explained_variance   | 0.0136       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 103          |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00565     |
# |    reward               | -0.084591046 |
# |    std                  | 1.17         |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 90           |
# |    time_elapsed         | 647          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.04980398   |
# |    clip_fraction        | 0.348        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.7        |
# |    explained_variance   | 0.00493      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 25.3         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.00473      |
# |    reward               | -0.053274386 |
# |    std                  | 1.17         |
# |    value_loss           | 92.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 91          |
# |    time_elapsed         | 654         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.048218768 |
# |    clip_fraction        | 0.417       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.7       |
# |    explained_variance   | 0.0728      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.37        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | -1.3979409  |
# |    std                  | 1.17        |
# |    value_loss           | 14.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 92          |
# |    time_elapsed         | 661         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.021789588 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.8       |
# |    explained_variance   | 0.0446      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.3        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0152     |
# |    reward               | -1.3635033  |
# |    std                  | 1.18        |
# |    value_loss           | 72.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 93          |
# |    time_elapsed         | 668         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.026447115 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.8       |
# |    explained_variance   | -0.00149    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 58.4        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00382    |
# |    reward               | -2.2102652  |
# |    std                  | 1.18        |
# |    value_loss           | 262         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 94           |
# |    time_elapsed         | 676          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.04765633   |
# |    clip_fraction        | 0.339        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -45.9        |
# |    explained_variance   | 0.0581       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 14.3         |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.00762     |
# |    reward               | -0.009128212 |
# |    std                  | 1.18         |
# |    value_loss           | 32           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 95          |
# |    time_elapsed         | 684         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.032003682 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -46         |
# |    explained_variance   | 0.0311      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 65.7        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0126     |
# |    reward               | -0.5368971  |
# |    std                  | 1.18        |
# |    value_loss           | 141         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 96          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.038014762 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -46         |
# |    explained_variance   | 0.0456      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.2        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00274    |
# |    reward               | 6.2501063   |
# |    std                  | 1.18        |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 97          |
# |    time_elapsed         | 699         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.081653535 |
# |    clip_fraction        | 0.391       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -46.1       |
# |    explained_variance   | 0.0972      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.5        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | 0.00166     |
# |    reward               | 0.24970838  |
# |    std                  | 1.19        |
# |    value_loss           | 39.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 283        |
# |    iterations           | 98         |
# |    time_elapsed         | 706        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.03465675 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -46.2      |
# |    explained_variance   | -0.0222    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 62.9       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.00529   |
# |    reward               | 0.21102075 |
# |    std                  | 1.19       |
# |    value_loss           | 94.1       |
# ----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device
# Logging to results/td3

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None
# Out:
# day: 2892, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 3798809.18
# total_reward: 2798809.18
# total_cost: 1367.75
# total_trades: 37622
# Sharpe: 0.793
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 103      |
# |    time_elapsed    | 111      |
# |    total_timesteps | 11572    |
# | train/             |          |
# |    actor_loss      | 138      |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11471    |
# |    reward          | 4.38984  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 98       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 63.2     |
# |    critic_loss     | 13.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 23043    |
# |    reward          | 4.38984  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 102      |
# |    time_elapsed    | 337      |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 63.4     |
# |    critic_loss     | 16.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34615    |
# |    reward          | 4.38984  |
# ---------------------------------
# day: 2892, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 3798809.18
# total_reward: 2798809.18
# total_cost: 1367.75
# total_trades: 37622
# Sharpe: 0.793
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 103      |
# |    time_elapsed    | 446      |
# |    total_timesteps | 46288    |
# | train/             |          |
# |    actor_loss      | 50.8     |
# |    critic_loss     | 14.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46187    |
# |    reward          | 4.38984  |
# ---------------------------------

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to results/sac

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None
# Out:
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 66       |
# |    time_elapsed    | 173      |
# |    total_timesteps | 11572    |
# | train/             |          |
# |    actor_loss      | 598      |
# |    critic_loss     | 131      |
# |    ent_coef        | 0.156    |
# |    ent_coef_loss   | -87.6    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11471    |
# |    reward          | 8.280132 |
# ---------------------------------
# day: 2892, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 7408208.00
# total_reward: 6408208.00
# total_cost: 116656.73
# total_trades: 66597
# Sharpe: 0.958
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 68       |
# |    time_elapsed    | 338      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 247      |
# |    critic_loss     | 118      |
# |    ent_coef        | 0.0495   |
# |    ent_coef_loss   | -134     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23043    |
# |    reward          | 9.197222 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 70       |
# |    time_elapsed    | 489      |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 120      |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.0158   |
# |    ent_coef_loss   | -158     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34615    |
# |    reward          | 8.040082 |
# ---------------------------------
# day: 2892, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 6363632.51
# total_reward: 5363632.51
# total_cost: 3533.71
# total_trades: 46870
# Sharpe: 0.896
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 71       |
# |    time_elapsed    | 648      |
# |    total_timesteps | 46288    |
# | train/             |          |
# |    actor_loss      | 67.4     |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.00519  |
# |    ent_coef_loss   | -125     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46187    |
# |    reward          | 8.788864 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 73       |
# |    time_elapsed    | 790      |
# |    total_timesteps | 57860    |
# | train/             |          |
# |    actor_loss      | 38.8     |
# |    critic_loss     | 7.59     |
# |    ent_coef        | 0.00195  |
# |    ent_coef_loss   | -18.1    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57759    |
# |    reward          | 8.771091 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 74       |
# |    time_elapsed    | 932      |
# |    total_timesteps | 69432    |
# | train/             |          |
# |    actor_loss      | 28.9     |
# |    critic_loss     | 6.53     |
# |    ent_coef        | 0.00207  |
# |    ent_coef_loss   | 1.99     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 69331    |
# |    reward          | 8.535367 |
# ---------------------------------

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## Save the trained agent
# Trained agents should have already been saved in the "trained_models" drectory after you run the code blocks above.
#
# For Colab users, the zip files should be at "./trained_models" or "/content/trained_models".
#
# For users running on your local environment, the zip files should be at "./trained_models".
